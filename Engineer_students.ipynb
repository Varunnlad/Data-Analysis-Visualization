# %% [markdown]
# <a href="https://colab.research.google.com/github/Varunnlad/Data-Analysis-Visualization/blob/master/Engineer_students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.head()
# Out:
#                              Student ID                 Name   Age  Gender  \
# 0  b37412a3-fa5c-40ca-b087-7109a47482d7                 Amit  21.0    Male
# 1  65001423-faeb-4d19-a550-8ea26133a34d         Tina Ballard  19.0    Male
# 2  228aaf1d-8710-4c8d-bfec-001b0df01f34                Meena  19.0  Female
# 3  1aa67474-e200-4157-ad54-c95aaa4d52a8  Christopher Morales  23.0    Male
# 4  5122db4a-14c8-44d7-b2f4-e869f69d3dd7            Siddharth  20.0    Male
#
#   Branch  Average GPA  Backlogs  Attendance (%)  \
# 0   MECH         6.99       0.0           70.45
# 1    ECE         6.46       0.0           65.45
# 2  CIVIL         7.08       0.0           84.79
# 3    ECE         6.92       2.0           62.26
# 4    EEE         7.09       0.0           97.12
#
#                                 Clubs                               Skills  \
# 0          Literary Society, Robotics  C++, Machine Learning, Python, Java
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student ID         1999 non-null   object
#  1   Name               2000 non-null   object
#  2   Age                1999 non-null   float64
#  3   Gender             1999 non-null   object
#  4   Branch             1999 non-null   object
#  5   Average GPA        1999 non-null   float64
#  6   Backlogs           1999 non-null   float64
#  7   Attendance (%)     1999 non-null   float64
#  8   Clubs              1999 non-null   object
#  9   Skills             1999 non-null   object
#  10  Internship Done    1999 non-null   object
#  11  Internship Domain  982 non-null    object
#  12  Placement Status   1999 non-null   object
#  13  Placement Domain   1032 non-null   object
#  14  CTC (LPA)          1999 non-null   float64
#  15  Alumni Path        1032 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Average GPA     Backlogs  Attendance (%)    CTC (LPA)  \
# count  1999.000000  1999.000000  1999.000000     1999.000000  1999.000000
# mean     20.474237     7.002616     0.966983       78.933147     5.795898
# std       1.728062     0.341148     0.990905       11.730931     6.563695
# min      18.000000     6.050000     0.000000       60.040000     0.000000
# 25%      19.000000     6.770000     0.000000       69.000000     0.000000
# 50%      21.000000     7.000000     1.000000       78.310000     3.460000
# 75%      22.000000     7.215000     1.000000       89.220000    11.260000
# max      23.000000     8.070000     5.000000       99.980000    19.990000
#
#           Sem1 GPA    Sem2 GPA     Sem3 GPA     Sem4 GPA     Sem5 GPA  \
# count  1999.000000  1999.00000  1999.000000  1999.000000  1999.000000
# mean      6.976433     7.08021     6.980905     6.961736     7.037894
# std       0.966329     1.03160     0.985273     0.983697     0.984407
# ...

# %% [markdown]
# After Analysing we understand that some categorical Terms should convert to category datatypes

# %%
df['Gender']= df['Gender'].astype('category')
df['Placement Status']= df['Placement Status'].astype('category')
df['Branch']= df['Branch'].astype('category')
df['Internship Done']= df['Internship Done'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 481 entries, 5 to 1998
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student ID         481 non-null    object
#  1   Name               481 non-null    object
#  2   Age                481 non-null    float64
#  3   Gender             481 non-null    category
#  4   Branch             481 non-null    category
#  5   Average GPA        481 non-null    float64
#  6   Backlogs           481 non-null    float64
#  7   Attendance (%)     481 non-null    float64
#  8   Clubs              481 non-null    object
#  9   Skills             481 non-null    object
#  10  Internship Done    481 non-null    category
#  11  Internship Domain  481 non-null    object
#  12  Placement Status   481 non-null    category
#  13  Placement Domain   481 non-null    object
#  14  CTC (LPA)          481 non-null    float64
#  15  Alumni Path        481 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Student ID              1
# Name                    0
# Age                     1
# Gender                  1
# Branch                  1
# Average GPA             1
# Backlogs                1
# Attendance (%)          1
# Clubs                   1
# Skills                  1
# Internship Done         1
# Internship Domain    1018
# Placement Status        1
# Placement Domain      968
# CTC (LPA)               1
# Alumni Path           968
# Sem1 GPA                1
# Sem2 GPA                1
# Sem3 GPA                1
# Sem4 GPA                1
# Sem5 GPA                1
# Sem6 GPA                1
# Sem7 GPA                1
# Sem8 GPA                1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Student ID           0
# Name                 0
# Age                  0
# Gender               0
# Branch               0
# Average GPA          0
# Backlogs             0
# Attendance (%)       0
# Clubs                0
# Skills               0
# Internship Done      0
# Internship Domain    0
# Placement Status     0
# Placement Domain     0
# CTC (LPA)            0
# Alumni Path          0
# Sem1 GPA             0
# Sem2 GPA             0
# Sem3 GPA             0
# Sem4 GPA             0
# Sem5 GPA             0
# Sem6 GPA             0
# Sem7 GPA             0
# Sem8 GPA             0
# dtype: int64

# %%
df['Gender'] = df['Gender'].str.strip().str.lower()
df['Placement Status'] = df['Placement Status'].str.strip().str.lower()
df['Internship Done'] = df['Internship Done'].str.strip().str.lower()

# %% [markdown]
# # Lets Visualize some relationships

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x="Placement Status")
plt.title("Placement Distributiuon")
# Out:
# Text(0.5, 1.0, 'Placement Distributiuon')

# %%
sns.boxplot(data=df, x="Placement Status", y="Average GPA")
plt.title("Placement vs CGPA")
# Out:
# Text(0.5, 1.0, 'Placement vs CGPA')

# %%
sns.boxplot(data=df, x='Placement Status', y='Backlogs')
plt.title('Backlogs by Placement')
# Out:
# Text(0.5, 1.0, 'Backlogs by Placement')

# %%
sns.boxplot(data=df, x='Placement Status', y='Attendance (%)')
plt.title('Attendance by Placement')
# Out:
# Text(0.5, 1.0, 'Attendance by Placement')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df , x="Branch", hue = "Placement Status")
plt.xticks(rotation=45)
plt.title("Placement Distribution by Branch")
# Out:
# Text(0.5, 1.0, 'Placement Distribution by Branch')

# %%
sem_cols = [col for col in df.columns if 'Sem' in col]
df[sem_cols].T.plot( legend=False,title="Semester GPA Trends (All Students Sampled)")
plt.xticks(rotation=45)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.]),
#  [Text(-1.0, 0, 'Sem8 GPA'),
#   Text(0.0, 0, 'Sem1 GPA'),
#   Text(1.0, 0, 'Sem2 GPA'),
#   Text(2.0, 0, 'Sem3 GPA'),
#   Text(3.0, 0, 'Sem4 GPA'),
#   Text(4.0, 0, 'Sem5 GPA'),
#   Text(5.0, 0, 'Sem6 GPA'),
#   Text(6.0, 0, 'Sem7 GPA'),
#   Text(7.0, 0, 'Sem8 GPA'),
#   Text(8.0, 0, '')])

# %%
df['GPA Growth'] = df['Sem8 GPA'] - df['Sem1 GPA']
sns.histplot(df['GPA Growth'])
plt.title('GPA Growth Distribution')
# Out:
# Text(0.5, 1.0, 'GPA Growth Distribution')

# %%
sns.countplot(data=df, x='Internship Done', hue='Placement Status')
plt.title("Internship vs Placement")
# Out:
# Text(0.5, 1.0, 'Internship vs Placement')

# %%
pivot = pd.crosstab(df['Internship Domain'], df['Placement Domain'])
sns.heatmap(pivot, annot=True, fmt='d', cmap='Blues')
plt.title("Internship Domain vs Placement Domain")
# Out:
# Text(0.5, 1.0, 'Internship Domain vs Placement Domain')

# %%
import numpy as np
numeric_cols = df.select_dtypes(include=np.number)
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Feature Correlation Heatmap')

# %% [markdown]
# # **Conclusion**
# # Students with GPA > 7.0 and no backlogs have 70–80% placement rate.
# #Higher attendance positively correlates with GPA and placement.
